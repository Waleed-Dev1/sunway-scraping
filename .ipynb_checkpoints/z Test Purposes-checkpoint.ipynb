# %%
import requests
import time
import pandas as pd
import json
from datetime import datetime
from apify_client import ApifyClient
from concurrent.futures import ThreadPoolExecutor, as_completed

# Set your API key
API_KEY = "AIzaSyDypG-8_jEmrcd6JJmcUWGbbYjLY32kM2s"

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key=API_KEY)

# %%
import pandas as pd

shops = pd.read_excel('stors (1).xlsx')
# rabwamall = pd.read_excel('Al-Rabwa_mall_shops_en.xlsx')

# %%
shops.sample(10)
# Out:
#       Year        Mall             CustName البراند          Brand  \
# 4201  2023        خريص  شركة امتياز العربية     NaN         NICHII
# 1164  2018      الربوة  شركة عبد الله العثي     NaN      Orchestra
# 3539  2020       بريدة  شركة اباريل للتجارة     NaN    Aeropostale
# 1979  2017     الاحساء  شركة التقنية الكبرى     NaN     Pappa Roti
# 3996  2021        حائل  شركة مارينا التجاري     NaN         Marina
# 1981  2016      الربوة  مؤسسة رمز الابداع ا     NaN    Tout Gouter
# 3251  2022       عنيزة  مؤسسة خصلة التجارية     NaN  أطياب المرشود
# 3735  2024     الاحساء  شركة الثماد للتجارة     NaN  The Body Shop
# 1591  2013       بريدة  شركة بركتين للتنمية     NaN         Nestro
# 5289  2024  حفر الباطن  شركة نما العربية لل     NaN           ميدي
#
#      ContractStatus
# 4201  Pending close
# 1164     Terminated
# 3539     Terminated
# 1979     Terminated
# 3996         Active
# 1981     Terminated
# 3251     Terminated
# 3735         Active
# 1591     Terminated
# ...

# %%
shops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5344 entries, 0 to 5343
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            5344 non-null   int64
#  1   Mall            5344 non-null   object
#  2   CustName        5344 non-null   object
#  3   البراند         147 non-null    object
#  4   Brand           5344 non-null   object
#  5   ContractStatus  5344 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 250.6+ KB

# %%
shops["Mall"].value_counts()
# Out:
# Mall
# الاحساء       1067
# الدمام         978
# الربوة         787
# حائل           658
# خريص           536
# بريدة          478
# عنيزة          343
# عرعر           338
# حفر الباطن      86
# الخفجي          50
# الرس            16
# عكيرشة           7
# Name: count, dtype: int64

# %%
# locations =['الورود،, Hafar Al Batin 39821, Saudi Arabia',
# 'Kharis Branch Rd, An Nasim Ash Sharqi, Riyadh 14241, Saudi Arabia',
# 'Prince Mohammed Bin Fahd Branch Rd, Al Shifa، Othaim Mall Othaim Mall،, Dammam 32236, Saudi Arabia']

# shops = shops[0:20]

# %%
def get_photo_url():
    photo_reference = 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/photos/AUy1YQ23uWXkSx5Xz7lYPkQMACkmjb00scBxDVJOYE6ntuNoKsCYqx8_24foVuUHLv9-yH3oLUPu-fSwTURwvU0E17ljKfJpiROCUIxrX0hcG24fDQmzvnY08k3c--Qhpy4al-fZMnamnNG4NdrkXiUk4fD2BtSNLIp5ALOR_ZnEecz4SvvM4hC1TQG1pyJlnJj_wwNRhvVW_eBQXK6FuTZcDWU-KwFuXJ08-ZQSSGJ_7CR7J-ZBvgpTjsNQfeaZiohYnNCHtATDI-U2CCC89Ga7c90xpL09yfHUKakSKj5-CM5PFTfHZK9nq_yci5T_SveOYXiMt5kLhlST7S-Sm2UWGXMETIQkYWiLW8sDpWkgasQcYcOqXNF5ndN3NHuP-9cwpZR-6gL0A68iKH-9bNCqdao48mNYrCmtp0Y7'
    photo_url = f"https://places.googleapis.com/v1/{photo_reference}/media?max_height_px=800&key={API_KEY}"
    photo_url = f"https://places.googleapis.com/v1/{photo_reference}/media?key={API_KEY}&maxWidthPx=400"
    
    return photo_url

# %%
get_photo_url()
# Out:
# 'https://places.googleapis.com/v1/places/ChIJ1w3s74hMzDER3SoXeAm32OA/photos/AUy1YQ23uWXkSx5Xz7lYPkQMACkmjb00scBxDVJOYE6ntuNoKsCYqx8_24foVuUHLv9-yH3oLUPu-fSwTURwvU0E17ljKfJpiROCUIxrX0hcG24fDQmzvnY08k3c--Qhpy4al-fZMnamnNG4NdrkXiUk4fD2BtSNLIp5ALOR_ZnEecz4SvvM4hC1TQG1pyJlnJj_wwNRhvVW_eBQXK6FuTZcDWU-KwFuXJ08-ZQSSGJ_7CR7J-ZBvgpTjsNQfeaZiohYnNCHtATDI-U2CCC89Ga7c90xpL09yfHUKakSKj5-CM5PFTfHZK9nq_yci5T_SveOYXiMt5kLhlST7S-Sm2UWGXMETIQkYWiLW8sDpWkgasQcYcOqXNF5ndN3NHuP-9cwpZR-6gL0A68iKH-9bNCqdao48mNYrCmtp0Y7/media?key=AIzaSyDypG-8_jEmrcd6JJmcUWGbbYjLY32kM2s&maxWidthPx=400'

# %%
def process_google_api_fetching(store, iteration):
    if iteration % 100 == 0:
        print(f"Processing records Number: {iteration}")
    
    # Create an empty DataFrame for this specific store
    detail = pd.DataFrame(index=[0])  # Single row DataFrame
    
    # First, add all the original store data
    for column in store.index:
        detail[column] = store[column]
    
    try:
        store_geocode = gmaps.geocode(f"{store['Brand']} {store['Mall']}, Saudi Arabia")
        place_id = store_geocode[0]['place_id']
        
        details_url = f"https://places.googleapis.com/v1/places/{place_id}"
        params = {
            "fields": "displayName,rating,reviews,international_phone_number,current_opening_hours,nationalPhoneNumber,formattedAddress,types,photos",
            "key": API_KEY
        }
        response = requests.get(details_url, params=params)
        data = response.json()
        
        # Add Google API data
        detail["google_name"] = data.get('displayName', {}).get('text', 'N/A')
        
        types_list = data.get('types', [])
        detail["google_category"] = ", ".join(types_list)
        
        detail["google_location"] = data.get('formattedAddress', 'N/A')
        
        # Process reviews
        reviews_list = []
        for rev in data.get('reviews', []):
            review_text = rev.get("originalText", {}).get("text", "No Review")
            review_rating = rev.get("rating", "N/A")
            review_time = rev.get("relativePublishTimeDescription", "N/A")
            reviews_list.append(f"review_rating:{review_rating}, text:{review_text}")
        
        detail["google_reviews"] = " | ".join(reviews_list) if reviews_list else "No Reviews"
        
        detail["google_rating"] = data.get('rating', 'N/A')
        detail["google_nationalPhoneNumber"] = data.get('nationalPhoneNumber', 'N/A')
        
        opening_hours = data.get('currentOpeningHours', {}).get("weekdayDescriptions", ["N/A"])
        detail["google_opening_hours"] = ", ".join(opening_hours)
        
        detail["google_internationalPhoneNumber"] = data.get('internationalPhoneNumber', 'N/A')
        detail["google_place_id"] = place_id
        
        return detail
        
    except Exception as e:
        logger.error(f"Error processing store {store['Brand']} in {store['Mall']}: {e}")
        # Return DataFrame with original store data but empty Google data
        for column in ['google_name', 'google_category', 'google_location', 'google_reviews', 
                       'google_rating', 'google_nationalPhoneNumber', 'google_opening_hours',
                       'google_internationalPhoneNumber', 'google_place_id']:
            detail[column] = 'N/A'
        return detail

# %%
import logging

# Configure your logger
logger = logging.getLogger(__name__)

# Initialize an empty list to store futures
futures = []

# Initialize an empty DataFrame to store all results
all_results = pd.DataFrame()

# Execute with ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=4) as executor:
    futures_to_stores = {}
    for row_index, (_, store) in enumerate(shops.iterrows()):
        future = executor.submit(
            process_google_api_fetching, store, row_index
        )
        futures_to_stores[future] = store
    
    for future in as_completed(futures_to_stores):
        try:
            result_df = future.result()
            all_results = pd.concat([all_results, result_df], ignore_index=True)
        except Exception as e:
            store = futures_to_stores[future]
            logger.error(f"Error in future execution for store {store['Brand']} in {store['Mall']}: {e}", exc_info=True)

# Now all_results contains all the data
print(f"Collected data for {len(all_results)} stores")
# Out:
# Proccesing records Number: 0

# %%
# store_geocode = gmaps.geocode(f"Bath & Body Works othaim mall, Saudi Arabia")
# place_id = store_geocode[0]['place_id']

# details_url = f"https://places.googleapis.com/v1/places/{place_id}"
# params = {
#     "fields": "displayName,rating,reviews,international_phone_number,current_opening_hours,nationalPhoneNumber,formattedAddress,types,photos",
#     "key": API_KEY
# }
# response = requests.get(details_url, params=params)
# data = response.json()

# %%
# data['photos'][0]

# %%
detail =pd.DataFrame()

detail["name"] = displayName
detail["category"] = types
detail["location"] = formattedAddress
detail["reviews"] = reviews
detail["rating"] = rating
detail["nationalPhoneNumber"]=nationalPhoneNumber
detail["opening_hours"]=opening_hours_list

# %%
detail.sample(10)
# Out:
#                            name  \
# 2470                      MANGO
# 4442                    Al Ahsa
# 3443                    Al Ahsa
# 5150  muvi Cinemas | موڤي سينما
# 4077                   Skechers
# 2268                       Hail
# 5272                       Hail
# 3540                   Buraydah
# 1478                    Al Ahsa
# 2762                Kiabi Rabwa
#
#                                                category  \
# 2470  clothing_store, store, point_of_interest, esta...
# 4442             administrative_area_level_2, political
# 3443             administrative_area_level_2, political
# 5150    movie_theater, point_of_interest, establishment
# 4077  shoe_store, clothing_store, sporting_goods_sto...
# 2268                                locality, political
# 5272                                locality, political
# 3540                                locality, political
# 1478             administrative_area_level_2, political
# ...

# %%
shops["name"] = displayName
shops["category"] = types
shops["location"] = formattedAddress
shops["reviews"] = reviews
shops["rating"] = rating
shops["nationalPhoneNumber"]=nationalPhoneNumber
shops["opening_hours"]=opening_hours_list

# %%
shops.sample(10)
# Out:
#       Year     Mall             CustName البراند                     Brand  \
# 5302  2024   الربوة   شركة ريكود للدعاية     NaN                     ريكود
# 3029  2021    عنيزة  شركة محمد عبد المحس     NaN                  Calliope
# 4934  2024    بريدة   شركة عبد الرحمن بن     NaN                  Al Daham
# 3862  2024     حائل  شركة عبدالله العثيم     NaN                  ICE SPOT
# 4357  2022  الاحساء  شركة الشايع الدولية     NaN                      Next
# 2172  2016     حائل   شركة مذاق السعودية     NaN              Fresh Burger
# 1147  2018     خريص  مطعم أضواء الديواني     NaN  الديوانية للقهوة العربية
# 505   2015  الاحساء  شركة عبد الله العثي     NaN               Boux Avenue
# 3725  2024   الدمام  شركة جزيرة الحلويات     NaN             Sweets Island
# 708   2016   الربوة   شركة الصفا للأدوية     NaN        The Beauty Secrets
#
#      ContractStatus                      name  \
# 5302  Pending close                 Ar Rabwah
# 3029     Terminated                  Calliope
# ...

# %%
shops.to_csv("store_FinalDetail.csv",encoding="utf-8-sig", index=False)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5344 entries, 0 to 5343
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 5344 non-null   object
#  1   category             5344 non-null   object
#  2   location             5344 non-null   object
#  3   reviews              5344 non-null   object
#  4   rating               5344 non-null   object
#  5   nationalPhoneNumber  5344 non-null   object
#  6   opening_hours        5344 non-null   object
# dtypes: object(7)
# memory usage: 292.4+ KB
