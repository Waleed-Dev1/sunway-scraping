# %%
import requests
import time
import pandas as pd
import json
from datetime import datetime

# Set your API key
API_KEY = "AIzaSyDypG-8_jEmrcd6JJmcUWGbbYjLY32kM2s"

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key=API_KEY)

# %%
store_geocode = gmaps.geocode(f"Boat Noodle - Sunway Pyramid, Malaysia")
place_id = store_geocode[0]['place_id']

# %%
details_url = f"https://places.googleapis.com/v1/places/{place_id}"

params = {
    "fields": "*",
    "key": API_KEY
}
response = requests.get(details_url, params=params)
data = response.json()

# %%
data
# Out:
# {'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA',
#  'id': 'ChIJ1w3s74hMzDER3SoXeAm32OA',
#  'types': ['restaurant',
#   'thai_restaurant',
#   'point_of_interest',
#   'food',
#   'establishment'],
#  'nationalPhoneNumber': '011-6846 0177',
#  'internationalPhoneNumber': '+60 11-6846 0177',
#  'formattedAddress': 'F1.79, Sunway Pyramid, 3, Jalan PJS 11/15, Bandar Sunway, 47500 Subang Jaya, Selangor, Malaysia',
#  'addressComponents': [{'longText': '3',
#    'shortText': '3',
#    'types': ['street_number'],
#    'languageCode': 'en-US'},
#   {'longText': 'Jalan PJS 11/15',
#    'shortText': 'Jalan PJS 11/15',
#    'types': ['route'],
#    'languageCode': 'ms'},
#   {'longText': 'Bandar Sunway',
#    'shortText': 'Bandar Sunway',
#    'types': ['sublocality_level_1', 'sublocality', 'political'],
#    'languageCode': 'en'},
#   {'longText': 'Subang Jaya',
#    'shortText': 'Subang Jaya',
#    'types': ['locality', 'political'],
#    'languageCode': 'en'},
#   {'longText': 'Selangor',
#    'shortText': 'Selangor',
#    'types': ['administrative_area_level_1', 'political'],
#    'languageCode': 'en'},
#   {'longText': 'Malaysia',
#    'shortText': 'MY',
#    'types': ['country', 'political'],
#    'languageCode': 'en'},
#   {'longText': '47500',
#    'shortText': '47500',
#    'types': ['postal_code'],
#    'languageCode': 'en-US'}],
#  'plusCode': {'globalCode': '6PM33JC4+P8',
#   'compoundCode': '3JC4+P8 Subang Jaya, Selangor, Malaysia'},
#  'location': {'latitude': 3.0718623999999997, 'longitude': 101.60586479999999},
#  'viewport': {'low': {'latitude': 3.0703754697084977,
#    'longitude': 101.60444841970849},
#   'high': {'latitude': 3.0730734302915015, 'longitude': 101.6071463802915}},
#  'rating': 4.3,
#  'googleMapsUri': 'https://maps.google.com/?cid=16201900910762732253',
#  'websiteUri': 'http://www.boatnoodle.com.my/',
#  'regularOpeningHours': {'openNow': True,
#   'periods': [{'open': {'day': 0, 'hour': 10, 'minute': 0},
#     'close': {'day': 0, 'hour': 21, 'minute': 30}},
#    {'open': {'day': 1, 'hour': 10, 'minute': 0},
#     'close': {'day': 1, 'hour': 21, 'minute': 30}},
#    {'open': {'day': 2, 'hour': 10, 'minute': 0},
#     'close': {'day': 2, 'hour': 21, 'minute': 30}},
#    {'open': {'day': 3, 'hour': 10, 'minute': 0},
#     'close': {'day': 3, 'hour': 21, 'minute': 30}},
#    {'open': {'day': 4, 'hour': 10, 'minute': 0},
#     'close': {'day': 4, 'hour': 21, 'minute': 30}},
#    {'open': {'day': 5, 'hour': 10, 'minute': 0},
#     'close': {'day': 5, 'hour': 21, 'minute': 30}},
#    {'open': {'day': 6, 'hour': 10, 'minute': 0},
#     'close': {'day': 6, 'hour': 21, 'minute': 30}}],
#   'weekdayDescriptions': ['Monday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Tuesday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Wednesday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Thursday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Friday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Saturday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Sunday: 10:00\u202fAM\u2009–\u20099:30\u202fPM'],
#   'nextCloseTime': '2025-03-06T13:30:00Z'},
#  'utcOffsetMinutes': 480,
#  'adrFormatAddress': 'F1.79, Sunway Pyramid, <span class="street-address">3, Jalan PJS 11/15</span>, <span class="extended-address">Bandar Sunway</span>, <span class="postal-code">47500</span> <span class="locality">Subang Jaya</span>, <span class="region">Selangor</span>, <span class="country-name">Malaysia</span>',
#  'businessStatus': 'OPERATIONAL',
#  'priceLevel': 'PRICE_LEVEL_MODERATE',
#  'userRatingCount': 698,
#  'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'iconBackgroundColor': '#FF9E67',
#  'displayName': {'text': 'Boat Noodle - Sunway Pyramid', 'languageCode': 'en'},
#  'primaryTypeDisplayName': {'text': 'Restaurant', 'languageCode': 'en-US'},
#  'takeout': True,
#  'delivery': True,
#  'dineIn': True,
#  'reservable': True,
#  'servesLunch': True,
#  'servesDinner': True,
#  'servesBeer': False,
#  'servesWine': False,
#  'servesBrunch': True,
#  'currentOpeningHours': {'openNow': True,
#   'periods': [{'open': {'day': 0,
#      'hour': 10,
#      'minute': 0,
#      'date': {'year': 2025, 'month': 3, 'day': 9}},
#     'close': {'day': 0,
#      'hour': 21,
#      'minute': 30,
#      'date': {'year': 2025, 'month': 3, 'day': 9}}},
#    {'open': {'day': 1,
#      'hour': 10,
#      'minute': 0,
#      'date': {'year': 2025, 'month': 3, 'day': 10}},
#     'close': {'day': 1,
#      'hour': 21,
#      'minute': 30,
#      'date': {'year': 2025, 'month': 3, 'day': 10}}},
#    {'open': {'day': 2,
#      'hour': 10,
#      'minute': 0,
#      'date': {'year': 2025, 'month': 3, 'day': 11}},
#     'close': {'day': 2,
#      'hour': 21,
#      'minute': 30,
#      'date': {'year': 2025, 'month': 3, 'day': 11}}},
#    {'open': {'day': 3,
#      'hour': 10,
#      'minute': 0,
#      'date': {'year': 2025, 'month': 3, 'day': 12}},
#     'close': {'day': 3,
#      'hour': 21,
#      'minute': 30,
#      'date': {'year': 2025, 'month': 3, 'day': 12}}},
#    {'open': {'day': 4,
#      'hour': 10,
#      'minute': 0,
#      'date': {'year': 2025, 'month': 3, 'day': 6}},
#     'close': {'day': 4,
#      'hour': 21,
#      'minute': 30,
#      'date': {'year': 2025, 'month': 3, 'day': 6}}},
#    {'open': {'day': 5,
#      'hour': 10,
#      'minute': 0,
#      'date': {'year': 2025, 'month': 3, 'day': 7}},
#     'close': {'day': 5,
#      'hour': 21,
#      'minute': 30,
#      'date': {'year': 2025, 'month': 3, 'day': 7}}},
#    {'open': {'day': 6,
#      'hour': 10,
#      'minute': 0,
#      'date': {'year': 2025, 'month': 3, 'day': 8}},
#     'close': {'day': 6,
#      'hour': 21,
#      'minute': 30,
#      'date': {'year': 2025, 'month': 3, 'day': 8}}}],
#   'weekdayDescriptions': ['Monday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Tuesday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Wednesday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Thursday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Friday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Saturday: 10:00\u202fAM\u2009–\u20099:30\u202fPM',
#    'Sunday: 10:00\u202fAM\u2009–\u20099:30\u202fPM'],
#   'nextCloseTime': '2025-03-06T13:30:00Z'},
#  'primaryType': 'restaurant',
#  'shortFormattedAddress': 'F1.79, Sunway Pyramid, 3, Jalan PJS 11/15, Bandar Sunway, Subang Jaya',
#  'reviews': [{'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/reviews/ChdDSUhNMG9nS0VJQ0FnSURfeTctcHd3RRAB',
#    'relativePublishTimeDescription': 'a month ago',
#    'rating': 4,
#    'text': {'text': "It's a fun spot for a quick and tasty bite! I sampled three boat noodle varieties:\n1. Pathumtani beef rice noodle (soy sauce based)\n2. Ayutthaya chicken spring noodle (stronger herbal broth)\n3. Creamy tom yum chicken rice noodle (seasonal, spicy and yummy!)\n\nPersonally, I prefer the chewier rice noodles.  The soups were all good – really depends on one's taste. I also ordered fried chicken skin; it was crunchy but average, still a fun snack. The Thai milk tea was decent.",
#     'languageCode': 'en'},
#    'originalText': {'text': "It's a fun spot for a quick and tasty bite! I sampled three boat noodle varieties:\n1. Pathumtani beef rice noodle (soy sauce based)\n2. Ayutthaya chicken spring noodle (stronger herbal broth)\n3. Creamy tom yum chicken rice noodle (seasonal, spicy and yummy!)\n\nPersonally, I prefer the chewier rice noodles.  The soups were all good – really depends on one's taste. I also ordered fried chicken skin; it was crunchy but average, still a fun snack. The Thai milk tea was decent.",
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Wong Teck Jung',
#     'uri': 'https://www.google.com/maps/contrib/115500349786770672418/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUdO6mRsxCLVC2048wQtIWaS0v-nVpQH1kaE3wX0RfFrArcLv5Y=s128-c0x00000000-cc-rp-mo-ba6'},
#    'publishTime': '2025-01-27T05:17:30.678386Z',
#    'flagContentUri': 'https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnSURfeTctcHd3RRAB&d=17924085&t=1',
#    'googleMapsUri': 'https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnSURfeTctcHd3RRAB!2m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add'},
#   {'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/reviews/ChZDSUhNMG9nS0VJQ0FnSURQa19taVZBEAE',
#    'relativePublishTimeDescription': '3 months ago',
#    'rating': 5,
#    'text': {'text': 'I was disappointed when Boat Noodle closed down at Sunway Pyramid, but I’m happy to say it’s recently reopened! The restaurant looks much better now—cleaner, more modern, and the interior design feels premium while still staying true to its brand identity. The service was quick and the staff friendly. My food arrived just five minutes after placing the order. Overall, I had a wonderful dining experience here',
#     'languageCode': 'en'},
#    'originalText': {'text': 'I was disappointed when Boat Noodle closed down at Sunway Pyramid, but I’m happy to say it’s recently reopened! The restaurant looks much better now—cleaner, more modern, and the interior design feels premium while still staying true to its brand identity. The service was quick and the staff friendly. My food arrived just five minutes after placing the order. Overall, I had a wonderful dining experience here',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Sarah Zolkefli',
#     'uri': 'https://www.google.com/maps/contrib/103361861509513102044/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjVQmZ9HQzyi6rtJfVLeF6eUy4BMJjP9_d4_yAlbNcF6QstJYpG8=s128-c0x00000000-cc-rp-mo'},
#    'publishTime': '2024-12-05T10:04:10.622982Z',
#    'flagContentUri': 'https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnSURQa19taVZBEAE&d=17924085&t=1',
#    'googleMapsUri': 'https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnSURQa19taVZBEAE!2m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add'},
#   {'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/reviews/ChZDSUhNMG9nS0VJQ0FnSUNQNjk2U2VBEAE',
#    'relativePublishTimeDescription': '3 months ago',
#    'rating': 5,
#    'text': {'text': 'Warm and welcoming staff made me feel right at home, offering great dish recommendations. The boat noodles were perfectly cooked with a flavorful broth, tender beef, and fresh herbs—small portions but packed with taste. The cozy ambiance and attentive service made the experience even better. Highly recommended for both food and hospitality!',
#     'languageCode': 'en'},
#    'originalText': {'text': 'Warm and welcoming staff made me feel right at home, offering great dish recommendations. The boat noodles were perfectly cooked with a flavorful broth, tender beef, and fresh herbs—small portions but packed with taste. The cozy ambiance and attentive service made the experience even better. Highly recommended for both food and hospitality!',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Karmyla',
#     'uri': 'https://www.google.com/maps/contrib/106589269558027336046/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjWLlYb6ToA3DE3c-Pvw1qkKbk4JNEirX-AyhmBi8jWZDB2LBwif=s128-c0x00000000-cc-rp-mo'},
#    'publishTime': '2024-11-28T05:43:27.425925Z',
#    'flagContentUri': 'https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnSUNQNjk2U2VBEAE&d=17924085&t=1',
#    'googleMapsUri': 'https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnSUNQNjk2U2VBEAE!2m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add'},
#   {'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/reviews/ChdDSUhNMG9nS0VJQ0FnSUNmaTUtYnF3RRAB',
#    'relativePublishTimeDescription': '2 months ago',
#    'rating': 5,
#    'text': {'text': 'I loveeeee the environment so much! Cosyyyy.\n\nService tiptop.\nThe foods were soooooo good. I had my normal meals Ayuthaya Rice Noodles and chicken skin. Soooo fresh and presentable as you can see in my photos.\n\nIced Lemon Tea is recommended, the sweetness level is just nice.\n\nKeep it up!!\n\nLocated in Sunway Pyramid. I came early, 10 am sharp. Like always, by 10 am Sunway already packed with people, so plan your trip here.',
#     'languageCode': 'en'},
#    'originalText': {'text': 'I loveeeee the environment so much! Cosyyyy.\n\nService tiptop.\nThe foods were soooooo good. I had my normal meals Ayuthaya Rice Noodles and chicken skin. Soooo fresh and presentable as you can see in my photos.\n\nIced Lemon Tea is recommended, the sweetness level is just nice.\n\nKeep it up!!\n\nLocated in Sunway Pyramid. I came early, 10 am sharp. Like always, by 10 am Sunway already packed with people, so plan your trip here.',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Wan Nur Saadiah',
#     'uri': 'https://www.google.com/maps/contrib/112465102438969828901/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocI5hu-QSO890eV2dQDb41MYqCC874U5QQWf74PGibjrg8wYYw=s128-c0x00000000-cc-rp-mo-ba3'},
#    'publishTime': '2025-01-01T14:54:29.333572Z',
#    'flagContentUri': 'https://www.google.com/local/review/rap/report?postId=ChdDSUhNMG9nS0VJQ0FnSUNmaTUtYnF3RRAB&d=17924085&t=1',
#    'googleMapsUri': 'https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChdDSUhNMG9nS0VJQ0FnSUNmaTUtYnF3RRAB!2m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add'},
#   {'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/reviews/ChZDSUhNMG9nS0VJQ0FnSUN2NnRmaVd3EAE',
#    'relativePublishTimeDescription': '2 months ago',
#    'rating': 5,
#    'text': {'text': 'A very warm welcome from all the staffs. The food and drink was good as usual because I just ordered my regular go-to meals. One of the staffs, Salsa who served me is very polite and friendly. I feel so at home even though I came to eat here alone. Overall I’m very satisfied and will come again.',
#     'languageCode': 'en'},
#    'originalText': {'text': 'A very warm welcome from all the staffs. The food and drink was good as usual because I just ordered my regular go-to meals. One of the staffs, Salsa who served me is very polite and friendly. I feel so at home even though I came to eat here alone. Overall I’m very satisfied and will come again.',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Afina Izwan',
#     'uri': 'https://www.google.com/maps/contrib/111378577097172145397/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a/ACg8
2e10!4m2!3m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add'},
#   {'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/photos/AUy1YQ2veD20gJAtJKDnUZh08lkdbYL2Gqu6MhC4fkfoCVzky730iui9yesoGTAVg41OjOvns7ixIiG2G6FYaJ3VGbMdUC0PiwK6qEVOZTQz1gz10lHkUDwiHav__uFLkFbopdeMAfJ1BKiBtoRdEKGH1zecuoBleItF3IdP7de4BBfMst6aUnY3UCv5TW5qZjHZMb7xqPZA1EqdC2QcTOT6MMYEcHRKGScBLwPRQgveGpnUfbYeqBm5TCRMWbCyV2G5-nt_H8g-_h7qfO5Pfcl0h4lw3swy4fnR_GVegNQr3rEbbimZkVNQR--j1ZkNOzPSVcgnvDk9h1bnnAunJFFv7Dj5lTimCQ7hh7fRSCjnUtc37UVbmYP9e0qgY9lMdZkDlwC3z2IZXYcBnlnaTn8yYIrAzPTLiRWDVg',
#    'widthPx': 3024,
#    'heightPx': 4032,
#    'authorAttributions': [{'displayName': 'intan rabiatul',
#      'uri': 'https://maps.google.com/maps/contrib/115268405042313077877',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjVXpL2tqr9jBTI1R0vFV2NdB4kWJAj2KaJjZrXkWdKqxi6cnic=s100-p-k-no-mo'}],
#    'flagContentUri': 'https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgIDPpeiW6QE&hl=en-US',
#    'googleMapsUri': 'https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgIDPpeiW6QE!2e10!4m2!3m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add'},
#   {'name': 'places/ChIJ1w3s74hMzDER3SoXeAm32OA/photos/AUy1YQ147uGez9t3CRLgJB_CZQ1SONpTAkkW94oUuYjvOm6jVpqNhpe3kOoRAATUWeq5U8J1dkGdQkmssQM8AXRRI1TKPb7d_nJsTUXV-ihuF9kJjS3e1LTG77SQ6mU9bHd3s5bAmgWEj5eHN2nv2S90IHdt_258gCB4WAAEq7qC-hL8u_DqLuFDNTfLI3Jbpu1vWVyfDnF0MJWCCNCJQgqPYe7tHgTk-MGLon2JlzOUNJmyr_Z-f_VdG2mHPZXxMh219PNaKLwLoWbia9ht-aP7Dc4Zd0aamTfydGT0Fw1kDcG-3TWhOEIum62knw3uUi60Y5g8FjzIuUYlXI14K1SEtyjHrKPO0PIGpc2j8mCLLGXN9PCdtrYGsuGeqjOBkMzvgxbZAAGOGQXU-LFluvZVkVdeLD_Z2CtffA',
#    'widthPx': 3600,
#    'heightPx': 4800,
#    'authorAttributions': [{'displayName': 'Coby Khor',
#      'uri': 'https://maps.google.com/maps/contrib/113533685430664313705',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjXBtsvjSmTrLJKd7VZs8o1lV2a1X4L7e1h2gjJM-YpOr_eNKKU=s100-p-k-no-mo'}],
#    'flagContentUri': 'https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sCIHM0ogKEICAgID_2NObzgE&hl=en-US',
#    'googleMapsUri': 'https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sCIHM0ogKEICAgID_2NObzgE!2e10!4m2!3m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add'}],
#  'outdoorSeating': False,
#  'liveMusic': False,
#  'servesDessert': True,
#  'servesCoffee': True,
#  'goodForChildren': True,
#  'goodForGroups': True,
#  'paymentOptions': {'acceptsCreditCards': True,
#   'acceptsDebitCards': True,
#   'acceptsCashOnly': False,
#   'acceptsNfc': True},
#  'accessibilityOptions': {'wheelchairAccessibleParking': True,
#   'wheelchairAccessibleEntrance': True,
#   'wheelchairAccessibleSeating': True},
#  'containingPlaces': [{'name': 'places/ChIJm21YdodMzDERJW_y1EmlGV4',
#    'id': 'ChIJm21YdodMzDERJW_y1EmlGV4'}],
#  'pureServiceAreaBusiness': False,
#  'addressDescriptor': {'landmarks': [{'name': 'places/ChIJm21YdodMzDERJW_y1EmlGV4',
#     'placeId': 'ChIJm21YdodMzDERJW_y1EmlGV4',
#     'displayName': {'text': 'Sunway Pyramid Shopping Mall',
#      'languageCode': 'en'},
#     'types': ['establishment', 'point_of_interest', 'shopping_mall'],
#     'spatialRelationship': 'WITHIN',
#     'straightLineDistanceMeters': 237.64824},
#    {'name': 'places/ChIJJTHt3YhMzDERvM3wesdMZds',
#     'placeId': 'ChIJJTHt3YhMzDERvM3wesdMZds',
#     'displayName': {'text': 'Sunway Lagoon', 'languageCode': 'en'},
#     'types': ['amusement_park',
#      'establishment',
#      'park',
#      'point_of_interest',
#      'tourist_attraction',
#      'zoo'],
#     'straightLineDistanceMeters': 291.74924},
#    {'name': 'places/ChIJw6QPkIdMzDERWGVORWEiIpo',
#     'placeId': 'ChIJw6QPkIdMzDERWGVORWEiIpo',
#     'displayName': {'text': 'Sunway Pyramid Convention Centre',
#      'languageCode': 'en'},
#     'types': ['establishment', 'point_of_interest'],
#     'straightLineDistanceMeters': 146.05566},
#    {'name': 'places/ChIJl9Tpx4dMzDER1tNtX-m1jzk',
#     'placeId': 'ChIJl9Tpx4dMzDER1tNtX-m1jzk',
#     'displayName': {'text': 'Seoul Garden @ Sunway Pyramid',
#      'languageCode': 'en'},
#     'types': ['establishment', 'food', 'point_of_interest', 'restaurant'],
#     'spatialRelationship': 'BESIDE',
#     'straightLineDistanceMeters': 12.496638},
#    {'name': 'places/ChIJv3RmJ4ZMzDERGK7F0EA1wY8',
#     'placeId': 'ChIJv3RmJ4ZMzDERGK7F0EA1wY8',
#     'displayName': {'text': 'Indah Villa', 'languageCode': 'en'},
#     'types': ['establishment', 'lodging', 'point_of_interest'],
#     'straightLineDistanceMeters': 193.51901}],
#   'areas': [{'name': 'places/ChIJmwJf3oZMzDER3GgA_gkeAoc',
#     'placeId': 'ChIJmwJf3oZMzDER3GgA_gkeAoc',
#     'displayName': {'text': 'Sunway Pyramid Shopping Mall',
#      'languageCode': 'en'},
#     'containment': 'WITHIN'},
#    {'name': 'places/ChIJwaubTHlMzDER2T04EVDOvhs',
#     'placeId': 'ChIJwaubTHlMzDER2T04EVDOvhs',
#     'displayName': {'text': 'Bandar Sunway', 'languageCode': 'en'},
#     'containment': 'WITHIN'},
#    {'name': 'places/ChIJf73ye4ZMzDERoBlU-x0B1R0',
#     'placeId': 'ChIJf73ye4ZMzDERoBlU-x0B1R0',
#     'displayName': {'text': 'Sunway Lagoon', 'languageCode': 'en'},
#     'containment': 'NEAR'}]},
#  'googleMapsLinks': {'directionsUri': "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x31cc4c88efec0dd7:0xe0d8b70978172add!3e0",
#   'placeUri': 'https://maps.google.com/?cid=16201900910762732253',
#   'writeAReviewUri': 'https://www.google.com/maps/place//data=!4m3!3m2!1s0x31cc4c88efec0dd7:0xe0d8b70978172add!12e1',
#   'reviewsUri': 'https://www.google.com/maps/place//data=!4m4!3m3!1s0x31cc4c88efec0dd7:0xe0d8b70978172add!9m1!1b1',
#   'photosUri': 'https://www.google.com/maps/place//data=!4m3!3m2!1s0x31cc4c88efec0dd7:0xe0d8b70978172add!10e5'},
#  'priceRange': {'startPrice': {'currencyCode': 'MYR', 'units': '20'},
#   'endPrice': {'currencyCode': 'MYR', 'units': '40'}},
#  'timeZone': {'id': 'Asia/Kuala_Lumpur'}}
